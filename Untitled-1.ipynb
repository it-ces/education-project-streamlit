# %%
import pandas as pd

# %%
df = pd.read_csv("Examen_Saber_Pro_Genericas_2024.txt", sep=';')
# Out:
# /tmp/ipykernel_32134/922137940.py:1: DtypeWarning:
#
# Columns (47,55) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df[[ "estu_depto_presentacion",
        "punt_global",
        "mod_competen_ciudada_punt",
        "mod_comuni_escrita_punt",
        "mod_ingles_punt",
        "mod_razona_cuantitat_punt",
        "estu_depto_presentacion",
        "punt_global",
        "mod_competen_ciudada_punt",
        "mod_comuni_escrita_punt",
        "inst_nombre_institucion",
        "estu_prgm_academico",
        "mod_ingles_punt",
        "mod_razona_cuantitat_punt",
          'punt_global',
        'inst_nombre_institucion',
        'estu_prgm_academico',
        'mod_competen_ciudada_punt',
        'mod_comuni_escrita_punt',
        'mod_ingles_punt', 
        'mod_razona_cuantitat_punt']].to_csv("SABER-PRO2024.csv", index=False)
